# %%
# importar bibliotecas

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sn
import xgboost as xgb
import lightgbm as lgbm
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier

import os
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

# %%
# abrir dataset

#dataset = pd.read_csv('D:\\archive\\features_kidney_cancer_VGG16.csv')
dataset = pd.read_csv("C:/Users/danie/Desktop/Projeto-SI2/DatasetFeatures_ResNet50_224x224/features_breast_cancer_ResNet50.csv")

# %%
# separar as colunas de dados e label

colunas_dados = []
for column in dataset.columns:
    if column != 'label':
        colunas_dados.append(column)
    else: 
        print("Achou")

X_full = dataset[colunas_dados]
Y_full = dataset['label']
X_full = np.array(X_full)
Y_full = np.array(Y_full)
np.random.shuffle(X_full)
np.random.shuffle(Y_full)

del dataset
# Out:
# Achou

# %%
# Separa em conjunto de teste e treino
x_train, x_test, y_train, y_test = train_test_split(X_full,Y_full,random_state=42,test_size=0.3)

del X_full, Y_full

# %%
# aplicar SVC
modelSVM = svm.SVC()
modelSVM.fit(x_train,y_train)

y_pred = modelSVM.predict(x_test)

matConf = confusion_matrix(y_test, y_pred)

# plota a matrix de confusao
df_cm = pd.DataFrame(matConf, range(2), range(2))
# plt.figure(figsize=(10,7))
sn.set(font_scale=1.4) # for label size
sn.heatmap(df_cm, annot=True, annot_kws={"size": 16}, xticklabels=['benign','malignant'], yticklabels=['benign','malignant']) # font size

acc = (matConf[0][0] + matConf[1][1])/len(y_pred)
print("Accuracy: ", acc)
# Out:
# Accuracy:  0.5096666666666667

# %%
# aplicar LSVC
modelSVM = svm.LinearSVC()
modelSVM.fit(x_train,y_train)

y_pred = modelSVM.predict(x_test)

matConf = confusion_matrix(y_test, y_pred)

# plota a matrix de confusao
df_cm = pd.DataFrame(matConf, range(2), range(2))
# plt.figure(figsize=(10,7))
sn.set(font_scale=1.4) # for label size
sn.heatmap(df_cm, annot=True, annot_kws={"size": 16}, xticklabels=['benign','malignant'], yticklabels=['benign','malignant']) # font size

acc = (matConf[0][0] + matConf[1][1])/len(y_pred)
print("Accuracy: ", acc)
# Out:
# Accuracy:  0.5153333333333333

# %%
# aplicar RF
modelSVM = RandomForestClassifier()
modelSVM.fit(x_train,y_train)

y_pred = modelSVM.predict(x_test)

matConf = confusion_matrix(y_test, y_pred)

# plota a matrix de confusao
df_cm = pd.DataFrame(matConf, range(2), range(2))
# plt.figure(figsize=(10,7))
sn.set(font_scale=1.4) # for label size
sn.heatmap(df_cm, annot=True, annot_kws={"size": 16}, xticklabels=['benign','malignant'], yticklabels=['benign','malignant']) # font size

acc = (matConf[0][0] + matConf[1][1])/len(y_pred)
print("Accuracy: ", acc)
# Out:
# Accuracy:  0.504

# %%
# aplicar LGBM
modelSVM = lgbm.LGBMClassifier()
modelSVM.fit(x_train,y_train)

y_pred = modelSVM.predict(x_test)

matConf = confusion_matrix(y_test, y_pred)

# plota a matrix de confusao
df_cm = pd.DataFrame(matConf, range(2), range(2))
# plt.figure(figsize=(10,7))
sn.set(font_scale=1.4) # for label size
sn.heatmap(df_cm, annot=True, annot_kws={"size": 16}, xticklabels=['benign','malignant'], yticklabels=['benign','malignant']) # font size

acc = (matConf[0][0] + matConf[1][1])/len(y_pred)
print("Accuracy: ", acc)
# Out:
# [LightGBM] [Info] Number of positive: 3544, number of negative: 3456
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 10.064165 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 17666333
# [LightGBM] [Info] Number of data points in the train set: 7000, number of used features: 99987
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.506286 -> initscore=0.025144
# [LightGBM] [Info] Start training from score 0.025144
# Accuracy:  0.49833333333333335

# %%
# aplicar xgb
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(y_test)
y_test_encoded = le.transform(y_test)
le.fit(y_train)
y_train_encoded = le.transform(y_train)
modelSVM = xgb.XGBClassifier()
modelSVM.fit(x_train,y_train_encoded)

y_pred = modelSVM.predict(x_test)

matConf = confusion_matrix(y_test_encoded, y_pred)

# plota a matrix de confusao
df_cm = pd.DataFrame(matConf, range(2), range(2))
# plt.figure(figsize=(10,7))
sn.set(font_scale=1.4) # for label size
sn.heatmap(df_cm, annot=True, annot_kws={"size": 16}, xticklabels=['benign','malignant'], yticklabels=['benign','malignant']) # font size

acc = (matConf[0][0] + matConf[1][1])/len(y_pred)
print("Accuracy: ", acc)
# Out:
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# Cell In[5], line 9
#       7 y_train_encoded = le.transform(y_train)
#       8 modelSVM = xgb.XGBClassifier()
# ----> 9 modelSVM.fit(x_train,y_train_encoded)
#      11 y_pred = modelSVM.predict(x_test)
#      13 matConf = confusion_matrix(y_test_encoded, y_pred)
#
# File c:\Users\danie\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py:726, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     724 for k, arg in zip(sig.parameters, args):
#     725     kwargs[k] = arg
# --> 726 return func(**kwargs)
#
# File c:\Users\danie\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\sklearn.py:1531, in XGBClassifier.fit(self, X, y, sample_weight, base_margin, eval_set, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights)
#    1511 model, metric, params = self._configure_fit(xgb_model, params)
#    1512 train_dmatrix, evals = _wrap_evaluation_matrices(
#    1513     missing=self.missing,
#    1514     X=X,
#    (...)
#    1528     feature_types=self.feature_types,
#    1529 )
# -> 1531 self._Booster = train(
#    1532     params,
#    1533     train_dmatrix,
#    1534     self.get_num_boosting_rounds(),
#    1535     evals=evals,
#    1536     early_stopping_rounds=self.early_stopping_rounds,
#    1537     evals_result=evals_result,
#    1538     obj=obj,
#    1539     custom_metric=metric,
#    1540     verbose_eval=verbose,
#    1541     xgb_model=model,
#    1542     callbacks=self.callbacks,
#    1543 )
#    1545 if not callable(self.objective):
#    1546     self.objective = params["objective"]
#
# File c:\Users\danie\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py:726, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     724 for k, arg in zip(sig.parameters, args):
#     725     kwargs[k] = arg
# --> 726 return func(**kwargs)
#
# File c:\Users\danie\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\training.py:181, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     179 if cb_container.before_iteration(bst, i, dtrain, evals):
#     180     break
# --> 181 bst.update(dtrain, iteration=i, fobj=obj)
#     182 if cb_container.after_iteration(bst, i, dtrain, evals):
#     183     break
#
# File c:\Users\danie\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py:2100, in Booster.update(self, dtrain, iteration, fobj)
#    2097 self._assign_dmatrix_features(dtrain)
#    2099 if fobj is None:
# -> 2100     _check_call(
#    2101         _LIB.XGBoosterUpdateOneIter(
#    2102             self.handle, ctypes.c_int(iteration), dtrain.handle
#    2103         )
#    2104     )
#    2105 else:
#    2106     pred = self.predict(dtrain, output_margin=True, training=True)
#
# File c:\Users\danie\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py:284, in _check_call(ret)
#     273 """Check the return value of C API call
#     274
#     275 This function will raise exception when error occurs.
#    (...)
#     281     return value from API calls
#     282 """
#     283 if ret != 0:
# --> 284     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
#
# XGBoostError: [13:33:55] C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-06abd128ca6c1688d-1\xgboost\xgboost-ci-windows\src\common\io.h:320: bad_malloc: Failed to allocate 23448717936 bytes.
